# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import pickle
import os

# %% [markdown]
# # RPKM

# %% [markdown]
# ## BCCA Cohort

# %%
# NCI
patient_arr_NCI = os.listdir("../Raw_Data/BCCA/NCI/")

for id, patient in enumerate(patient_arr_NCI):

    name = patient.rsplit('.')[0]
    temp = pd.read_csv(fr"..\Raw_Data\BCCA\NCI\{patient}", sep="\t").set_index("gene").drop(["raw_counts", "median_length_normalized"], axis=1)
    temp = temp.rename(columns={'RPKM':name})

    if id == 0:
        df_BCCA_RPKM = temp
        continue

    df_BCCA_RPKM = df_BCCA_RPKM.join(temp)

# FHCRC
patient_arr_FHCRC = os.listdir("../Raw_Data/BCCA/FHCRC/")

for id, patient in enumerate(patient_arr_FHCRC):

    name = patient.rsplit('.')[0]

    if name in df_BCCA_RPKM: # Only PASIEJ seems to be duplicated
        name = name + "_second"

    temp = pd.read_csv(fr"..\Raw_Data\BCCA\FHCRC\{patient}", sep="\t").set_index("gene").drop(["raw_counts", "median_length_normalized"], axis=1)
    temp = temp.rename(columns={'RPKM':name})
    df_BCCA_RPKM = df_BCCA_RPKM.join(temp)

# %%
df_BCCA_NCI_RPKM = df_BCCA_RPKM.iloc[:, :357]
df_BCCA_FHCRC_RPKM = df_BCCA_RPKM.iloc[:,358:]

# %%
df_BCCA_FHCRC_RPKM
# Out:
#                  TARGET-00-BM3897-14A-01R  TARGET-00-BM3969-14A-01R  \
# gene
# ENSG00000000457                    5.2943                    6.9478
# ENSG00000000460                    2.4561                    3.2342
# ENSG00000000938                  102.4798                  104.4015
# ENSG00000000971                    0.5452                    0.5493
# ENSG00000001460                    0.6167                    0.6589
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.0000
# ENSG00000265161                    0.0000                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.0000                    0.0000
#
#                  TARGET-00-BM4203-14A-01R  TARGET-00-BM4404-14A-01R  \
# gene
# ENSG00000000457                    4.8332                    5.9712
# ENSG00000000460                    2.8471                    3.3871
# ENSG00000000938                   96.5721                   85.7130
# ENSG00000000971                    0.4259                    1.1093
# ENSG00000001460                    0.6567                    0.7275
# ...                                   ...                       ...
# ENSG00000263502                    0.0712                    0.0000
# ENSG00000265161                    0.0000                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.0000                    0.0000
#
#                  TARGET-00-BM4473-14A-01R  TARGET-00-BM4508-14A-01R  \
# gene
# ENSG00000000457                    2.9392                    4.0830
# ENSG00000000460                    2.9883                    3.9522
# ENSG00000000938                  105.4388                   77.1029
# ENSG00000000971                    0.5124                    0.4003
# ENSG00000001460                    0.2775                    0.5732
# ...                                   ...                       ...
# ENSG00000263502                    0.6263                    0.0000
# ENSG00000265161                    0.0000                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    3.3095                    3.3299
#
#                  TARGET-00-BM4616-14A-01R  TARGET-00-BM4641-14A-01R  \
# gene
# ENSG00000000457                    3.2640                    3.1688
# ENSG00000000460                    2.0735                    2.9869
# ENSG00000000938                   84.5942                   76.2609
# ENSG00000000971                    0.9964                    0.7361
# ENSG00000001460                    0.4482                    0.5136
# ...                                   ...                       ...
# ENSG00000263502                    0.4419                    0.0905
# ENSG00000265161                    0.0000                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    1.6069                    2.0272
#
#                  TARGET-00-BM5682-14A-01R  TARGET-00-BM5751-14A-01R  ...  \
# gene                                                                 ...
# ENSG00000000457                    7.3772                    5.4273  ...
# ENSG00000000460                    2.8351                    3.1420  ...
# ENSG00000000938                   81.7504                   93.1046  ...
# ENSG00000000971                    0.6344                    0.9214  ...
# ENSG00000001460                    0.6559                    0.6124  ...
# ...                                   ...                       ...  ...
# ENSG00000263502                    0.0000                    0.0000  ...
# ENSG00000265161                    0.0000                    0.0000  ...
# ENSG00000265197                    0.0000                    0.0000  ...
# ENSG00000266220                    0.0000                    0.0000  ...
# ENSG00000267793                    0.0000                    0.0000  ...
#
#                  TARGET-20-PAXMKU-09A-01R  TARGET-20-PAXMLI-09A-01R  \
# gene
# ENSG00000000457                    1.8419                    2.3625
# ENSG00000000460                    0.3634                    2.5928
# ENSG00000000938                   21.3486                   71.7175
# ENSG00000000971                    0.0321                    0.0804
# ENSG00000001460                    0.3163                    0.4284
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.0000
# ENSG00000265161                    0.0000                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    1.3420                    0.5466
#
#                  TARGET-20-PAXMLN-09A-01R  TARGET-20-PAXMLW-09A-01R  \
# gene
# ENSG00000000457                    2.7024                    3.2384
# ENSG00000000460                    2.4894                    2.2811
# ENSG00000000938                   44.4386                   37.0442
# ENSG00000000971                    0.0238                    1.3305
# ENSG00000001460                    0.2785                    0.3282
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.2000
# ENSG00000265161                    0.0000                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.0000                    0.0000
#
#                  TARGET-20-PAXMNG-09A-01R  TARGET-20-PAXMNR-09A-01R  \
# gene
# ENSG00000000457                    2.7524                    1.4406
# ENSG00000000460                    2.4866                    1.5371
# ENSG00000000938                   44.3165                   58.8058
# ENSG00000000971                    0.0736                    0.0895
# ENSG00000001460                    0.4806                    0.2419
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.5491
# ENSG00000265161                    0.0000                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.0000                    1.0079
#
#                  TARGET-20-PAXMPF-09A-01R  TARGET-20-PAXMPG-09A-01R  \
# gene
# ENSG00000000457                    2.1114                    7.9423
# ENSG00000000460                    0.8846                    6.1259
# ENSG00000000938                    6.2139                    9.0036
# ENSG00000000971                    0.0717                   11.4298
# ENSG00000001460                    0.1274                    0.5180
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.0000
# ENSG00000265161                    0.0000                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.0000                    0.0000
#
#                  TARGET-20-PAXMPW-09A-01R  TARGET-20-PAXMRA-09A-01R
# gene
# ENSG00000000457                    2.4903                    3.7949
# ENSG00000000460                    2.6607                    4.0643
# ENSG00000000938                    3.5467                   78.9296
# ENSG00000000971                    0.1016                    0.6201
# ENSG00000001460                    0.5688                    0.5299
# ...                                   ...                       ...
# ENSG00000263502                    2.4160                    0.0000
# ENSG00000265161                    0.0000                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    2.5912                    0.0000
#
# [58450 rows x 1117 columns]

# %%
df_BCCA_NCI_RPKM
# Out:
#                  TARGET-20-PABGKN-09A-01R  TARGET-20-PABHET-03A-02R  \
# gene
# ENSG00000000457                    1.6725                    3.6519
# ENSG00000000460                    0.6485                    1.8215
# ENSG00000000938                   23.9563                    0.8534
# ENSG00000000971                    0.0859                    0.0137
# ENSG00000001460                    0.3017                    0.6682
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.0000
# ENSG00000265161                    0.0000                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0668                    0.0000
# ENSG00000267793                    0.0000                    0.0000
#
#                  TARGET-20-PABHKY-03A-02R  TARGET-20-PABLDZ-04A-01R  \
# gene
# ENSG00000000457                    2.9367                    1.5071
# ENSG00000000460                    3.4803                    0.1419
# ENSG00000000938                    2.6922                    4.3848
# ENSG00000000971                    0.2140                    0.0000
# ENSG00000001460                    0.3216                    0.3007
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.0000
# ENSG00000265161                    0.0000                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.0000                    0.0000
#
#                  TARGET-20-PABLDZ-09A-04R  TARGET-20-PACDZR-09A-02R  \
# gene
# ENSG00000000457                    1.1663                    1.5698
# ENSG00000000460                    2.1339                    0.8192
# ENSG00000000938                    6.3841                    1.1538
# ENSG00000000971                    0.4443                    0.1052
# ENSG00000001460                    0.3225                    0.3709
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.0000
# ENSG00000265161                    0.0000                    0.1279
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.0000                    0.0000
#
#                  TARGET-20-PADDXZ-03A-02R  TARGET-20-PADYIR-04A-01R  \
# gene
# ENSG00000000457                    0.8150                    1.4018
# ENSG00000000460                    0.9016                    1.3998
# ENSG00000000938                    1.2950                   15.0849
# ENSG00000000971                    0.7787                    0.0965
# ENSG00000001460                    0.1032                    0.4487
# ...                                   ...                       ...
# ENSG00000263502                    0.0097                    0.0000
# ENSG00000265161                    0.0000                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.2438                    0.4976
#
#                  TARGET-20-PADYIR-09A-01R  TARGET-20-PADZCG-04A-01R  ...  \
# gene                                                                 ...
# ENSG00000000457                    1.7467                    2.7219  ...
# ENSG00000000460                    0.3215                    0.3922  ...
# ENSG00000000938                   31.2250                   59.4319  ...
# ENSG00000000971                    0.0229                    0.4646  ...
# ENSG00000001460                    0.2035                    0.2697  ...
# ...                                   ...                       ...  ...
# ENSG00000263502                    0.0000                    0.0000  ...
# ENSG00000265161                    0.0000                    0.0000  ...
# ENSG00000265197                    0.0000                    0.0000  ...
# ENSG00000266220                    0.0000                    0.0000  ...
# ENSG00000267793                    0.5465                    0.0000  ...
#
#                  TARGET-21-PATHIU-09A-01R  TARGET-21-PATISD-09A-01R  \
# gene
# ENSG00000000457                    1.5075                    3.1071
# ENSG00000000460                    2.8657                    2.2841
# ENSG00000000938                    5.8015                    9.1640
# ENSG00000000971                    0.3868                    0.2824
# ENSG00000001460                    0.7602                    1.0854
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.0000
# ENSG00000265161                    0.0000                    0.1474
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.4810                    0.6104
#
#                  TARGET-21-PATISD-41A-01R  TARGET-21-PATJMY-09A-01R  \
# gene
# ENSG00000000457                    1.0835                    2.1674
# ENSG00000000460                    0.5319                    1.4086
# ENSG00000000938                    1.3610                    8.7331
# ENSG00000000971                    0.3326                    0.0450
# ENSG00000001460                    0.7130                    0.6371
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.0000
# ENSG00000265161                    0.8252                    0.0000
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.1170                    0.2526
#
#                  TARGET-21-PATJMY-41A-01R  TARGET-21-PATKBK-03A-01R  \
# gene
# ENSG00000000457                    1.5087                    2.2020
# ENSG00000000460                    1.8402                    2.8382
# ENSG00000000938                    3.4795                   27.3860
# ENSG00000000971                    0.8559                    5.9938
# ENSG00000001460                    0.6100                    1.6049
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.0000
# ENSG00000265161                    0.0000                    0.1863
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.1874                    0.3094
#
#                  TARGET-21-PATKBK-41A-02R  TARGET-21-PATKKJ-09A-01R  \
# gene
# ENSG00000000457                    0.8998                    2.8004
# ENSG00000000460                    0.7880                    1.5490
# ENSG00000000938                   24.4414                    8.8184
# ENSG00000000971                    1.0266                    0.0330
# ENSG00000001460                    0.4540                    1.2913
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.0000
# ENSG00000265161                    0.4637                    0.1810
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.0456                    0.0000
#
#                  TARGET-21-PATKKJ-41A-01R  TARGET-21-PATKWH-09A-01R
# gene
# ENSG00000000457                    3.0036                    3.1459
# ENSG00000000460                    1.6758                    2.4930
# ENSG00000000938                    6.2060                    8.2413
# ENSG00000000971                    0.1079                    0.0716
# ENSG00000001460                    1.5164                    1.0078
# ...                                   ...                       ...
# ENSG00000263502                    0.0000                    0.0000
# ENSG00000265161                    1.0269                    0.1601
# ENSG00000265197                    0.0000                    0.0000
# ENSG00000266220                    0.0000                    0.0000
# ENSG00000267793                    0.0000                    0.9385
#
# [58450 rows x 357 columns]

# %% [markdown]
# ## FHCRC Low Depth
# Only ___ genes/features

# %%
df_FHCRC_LD = pd.read_csv(r"..\Raw_Data\FHCRC_Low_Depth\TARGET_NBM_AML_QuantileNormalized_RPKM.txt", sep="\t")
df_FHCRC_LD = df_FHCRC_LD.set_index("gene_name").sort_index(axis=0).rename({"gene_name":"Symbol"}, axis=1).drop("gene_id", axis=1)

# %%
df_FHCRC_LD
# Out:
#            TARGET-00-BM3897-14A-01R  TARGET-00-BM3969-14A-01R  \
# gene_name
# 5S_rRNA                    0.000000                  0.000000
# 7SK                        0.324697                  1.420539
# 7SK                        0.000000                  0.000000
# 7SK                        0.000000                  0.000000
# 7SK                        0.442916                  0.227439
# ...                             ...                       ...
# snoU2_19                   0.000000                  0.959464
# snoZ5                      0.000000                  0.472026
# snoZ6                      2.361722                  1.859639
# snoZ6                      0.000000                  0.000000
# snoZ6                      1.726768                  2.095226
#
#            TARGET-00-BM4003-14A-01R  TARGET-00-BM4387-14A-01R  \
# gene_name
# 5S_rRNA                    0.000000                  0.000000
# 7SK                        1.364756                  1.419206
# 7SK                        0.424993                  0.518495
# 7SK                        0.000000                  0.000000
# 7SK                        1.931046                  1.217008
# ...                             ...                       ...
# snoU2_19                   0.957293                  0.728138
# snoZ5                      0.644049                  0.000000
# snoZ6                      2.474814                  3.107353
# snoZ6                      0.000000                  0.000000
# snoZ6                      2.563416                  2.237051
#
#            TARGET-00-BM4404-14A-01R  TARGET-00-BM4473-14A-01R  \
# gene_name
# 5S_rRNA                    0.000000                  0.000000
# 7SK                        1.552453                  0.986300
# 7SK                        0.287312                  0.564635
# 7SK                        0.000000                  0.000000
# 7SK                        0.521778                  2.489073
# ...                             ...                       ...
# snoU2_19                   1.465901                  1.403054
# snoZ5                      0.000000                  0.000000
# snoZ6                      2.109598                  4.432049
# snoZ6                      0.000000                  0.000000
# snoZ6                      2.343361                  4.210908
#
#            TARGET-00-BM4508-14A-01R  TARGET-00-BM4616-14A-01R  \
# gene_name
# 5S_rRNA                    0.000000                  0.000000
# 7SK                        1.293730                  0.768513
# 7SK                        0.384057                  0.415093
# 7SK                        0.000000                  0.000000
# 7SK                        1.348023                  2.542647
# ...                             ...                       ...
# snoU2_19                   1.147622                  2.547466
# snoZ5                      0.000000                  0.000000
# snoZ6                      1.871274                  2.072561
# snoZ6                      0.000000                  0.000000
# snoZ6                      2.562244                  2.569765
#
#            TARGET-00-BM4641-14A-01R  TARGET-00-BM5108-14A-01R  ...  \
# gene_name                                                      ...
# 5S_rRNA                    0.000000                  0.000000  ...
# 7SK                        2.272870                  1.707450  ...
# 7SK                        0.201812                  0.415093  ...
# 7SK                        0.000000                  0.000000  ...
# 7SK                        3.019730                  1.193949  ...
# ...                             ...                       ...  ...
# snoU2_19                   1.160767                  1.804725  ...
# snoZ5                      0.000000                  0.383759  ...
# snoZ6                      3.340553                  2.151520  ...
# snoZ6                      0.000000                  0.000000  ...
# snoZ6                      3.441337                  2.004762  ...
#
#            TARGET-20-PASRRU-03A-01R  TARGET-20-PASSGZ-03A-01R  \
# gene_name
# 5S_rRNA                    0.000059                  0.000116
# 7SK                        0.719817                  1.913875
# 7SK                        0.000059                  0.000116
# 7SK                        0.000059                  0.000116
# 7SK                        0.920212                  1.865614
# ...                             ...                       ...
# snoU2_19                   1.908510                  0.897283
# snoZ5                      0.000059                  0.000116
# snoZ6                      4.529171                  1.477704
# snoZ6                      0.000059                  0.000116
# snoZ6                      3.957166                  1.575857
#
#            TARGET-20-PASZEI-09A-01R  TARGET-20-PATBFF-09A-01R  \
# gene_name
# 5S_rRNA                    0.000031                  0.000000
# 7SK                        2.427331                  2.473938
# 7SK                        0.270313                  1.325058
# 7SK                        0.000031                  0.000000
# 7SK                        1.194061                  2.334128
# ...                             ...                       ...
# snoU2_19                   3.359764                  3.674161
# snoZ5                      0.000031                  0.000000
# snoZ6                      2.377127                  2.949207
# snoZ6                      0.000031                  0.000000
# snoZ6                      2.858629                  2.254859
#
#            TARGET-20-PATBXU-09A-01R  TARGET-20-PATCHL-09A-01R  \
# gene_name
# 5S_rRNA                    0.644998                  0.000000
# 7SK                        0.755621                  2.344787
# 7SK                        2.874587                  1.327468
# 7SK                        0.000000                  0.000000
# 7SK                        2.596535                  2.575473
# ...                             ...                       ...
# snoU2_19                   3.679036                  3.980905
# snoZ5                      0.000000                  0.000000
# snoZ6                      3.570776                  0.736799
# snoZ6                      0.000000                  0.000000
# snoZ6                      2.972215                  0.437157
#
#            TARGET-20-PATEAF-09A-01R  TARGET-20-PATEYS-09A-01R  \
# gene_name
# 5S_rRNA                    0.000000                  0.000000
# 7SK                        1.947442                  1.178252
# 7SK                        0.471681                  0.000000
# 7SK                        0.000000                  0.000000
# 7SK                        3.105347                  1.393537
# ...                             ...                       ...
# snoU2_19                   1.505096                  3.217457
# snoZ5                      0.000000                  0.000000
# snoZ6                      1.709431                  2.845489
# snoZ6                      0.000000                  0.000000
# snoZ6                      2.202260                  2.996598
#
#            TARGET-20-PATJWG-09A-01R  TARGET-20-PATKLS-09A-01R
# gene_name
# 5S_rRNA                    0.000075                  0.000000
# 7SK                        1.992186                  0.464341
# 7SK                        2.100311                  2.403681
# 7SK                        0.000075                  0.000000
# 7SK                        4.599373                  2.691710
# ...                             ...                       ...
# snoU2_19                   2.587730                  3.875151
# snoZ5                      0.902713                  0.000000
# snoZ6                      2.598018                  2.942005
# snoZ6                      0.000075                  1.016678
# snoZ6                      2.429649                  2.963529
#
# [28357 rows x 493 columns]

# %%
pd.read_csv(r"..\Raw_Data\FHCRC_AAML0031_AAML0631\TARGET-20-CMS-50A-01R.transcript.quantification.txt", sep="\t")

# %% [markdown]
# ## NCI_Meerzaman
# Couldn't find metadata

# %%
patient_arr_NCI_M = os.listdir("../Raw_Data/NCI_Meerzaman/")

for id, patient in enumerate(patient_arr_NCI_M):

    name = patient.rsplit('.')[0]
    temp = pd.read_csv(fr"..\Raw_Data\NCI_Meerzaman\{patient}", sep="\t").set_index("gene").drop(["raw_count"], axis=1)
    temp = temp.rename(columns={'rpkm':name})

    if id == 0:
        df_NCI_M_RPKM = temp
        continue

    df_NCI_M_RPKM = df_NCI_M_RPKM.join(temp)

# %%
df_NCI_M_RPKM
# Out:
#                   AML_23196      AML_23350      AML_36048      AML_51040  \
# gene
# 7SK                1.188330       1.573743       1.331052       2.106116
# A1BG               0.057874       0.052547       0.079104       0.077283
# A1CF               0.000000       0.000000       0.000000       0.018174
# A2LD1              0.077018       0.037462       0.070730       0.026200
# A2M                0.239750       0.051829       0.047929       0.000000
# ...                     ...            ...            ...            ...
# snoZ6              0.000000       0.000000       0.000000       0.000000
# snosnR60_Z15       0.000000       0.000000       0.000000       0.117133
# snosnR66           0.000000       0.000000       0.000000       0.000000
# yR211F11.2         0.000000       0.000000       0.000000       0.000000
# no_feature    143653.748622  178245.255003  190297.664802  248523.556471
#
#                   AML_63761      AML_66841     AML_709039     AML_716200  \
# gene
# 7SK                1.127671       1.131382       2.032897       1.710742
# A1BG               0.049906       0.068982       0.005036       0.015614
# A1CF               0.000000       0.000000       0.000000       0.000000
# A2LD1              0.162264       0.207761       0.063564       0.038960
# A2M                0.481058       1.616846       0.477394       0.308007
# ...                     ...            ...            ...            ...
# snoZ6              0.000000       0.000000       0.000000       0.000000
# snosnR60_Z15       0.000000       0.000000       0.000000       0.000000
# snosnR66           0.000000       0.000000       0.000000       0.000000
# yR211F11.2         0.000000       0.000000       0.000000       0.000000
# no_feature    150728.515949  102831.371868  249568.693972  215971.038366
#
#                  AML_719261     AML_723026  ...     AML_787870     AML_789920  \
# gene                                        ...
# 7SK                3.128592       1.070326  ...       0.811946       1.299897
# A1BG               0.000727       0.006411  ...       0.032627       0.015974
# A1CF               0.036073       0.000000  ...       0.000000       0.000000
# A2LD1              0.052004       0.104230  ...       0.326159       0.073718
# A2M                1.973425       0.358450  ...       0.077356       0.054637
# ...                     ...            ...  ...            ...            ...
# snoZ6              0.000000       0.000000  ...       0.000000       0.000000
# snosnR60_Z15       0.000000       0.000000  ...       0.000000       0.000000
# snosnR66           0.000000       0.000000  ...       0.000000       0.000000
# yR211F11.2         0.643481       0.257944  ...       0.000000       0.000000
# no_feature    318629.832127  141733.339272  ...  113402.438757  146783.508650
#
#                  AML_790021     AML_790059     AML_790201     AML_790790  \
# gene
# 7SK                2.606980       1.153559       3.931993       2.066668
# A1BG               0.031502       0.047799       0.015282       0.042508
# A1CF               0.000000       0.000000       0.000000       0.000000
# A2LD1              0.034667       0.156249       0.035263       0.094428
# A2M                0.657763       0.119894       0.229994       0.078386
# ...                     ...            ...            ...            ...
# snoZ6              0.000000       0.000000       0.508201       0.272176
# snosnR60_Z15       0.000000       0.000000       0.000000       0.000000
# snosnR66           0.000000       0.000000       0.000000       0.000000
# yR211F11.2         0.000000       0.000000       1.745336       0.000000
# no_feature    277897.329088  147338.803251  405911.064859  233229.325358
#
#                  AML_794421     AML_794537     AML_794690     AML_798231
# gene
# 7SK                2.780977       2.890522       1.413423       0.950674
# A1BG               0.032306       0.041250       0.013758       0.058086
# A1CF               0.000000       0.000000       0.000000       0.000000
# A2LD1              0.067308       0.122943       0.255498       0.043644
# A2M                0.119727       1.457935       0.706968       0.000000
# ...                     ...            ...            ...            ...
# snoZ6              0.323341       0.787476       0.000000       0.000000
# snosnR60_Z15       0.000000       0.244290       0.000000       0.000000
# snosnR66           0.000000       0.000000       0.000000       0.000000
# yR211F11.2         0.000000       0.000000       0.000000       0.000000
# no_feature    269683.021727  308707.023492  179345.614074  143425.134099
#
# [51887 rows x 66 columns]

# %% [markdown]
# ## FHCRC_AAML0031_AAML0631
# Cohort has no header

# %%
pd.read_csv(r"..\Raw_Data\FHCRC_AAML0031_AAML0631\TARGET-20-CMS-50A-01R.transcript.quantification.txt", sep="\t")
# Out:
# C:\Users\sckaffs.fernando\AppData\Local\Temp\ipykernel_8580\4058703429.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(r"..\Raw_Data\FHCRC_AAML0031_AAML0631\TARGET-20-CMS-50A-01R.transcript.quantification.txt", sep="\t")
#        ENSG00000000457  merged_ENSG00000000457  1  169821804  169863408  -  \
# 0      ENSG00000000460  merged_ENSG00000000460  1  169631245  169823221  +
# 1      ENSG00000000938  merged_ENSG00000000938  1   27938575   27961788  -
# 2      ENSG00000000971  merged_ENSG00000000971  1  196621008  196716634  +
# 3      ENSG00000001460  merged_ENSG00000001460  1   24683489   24743424  -
# 4      ENSG00000001461  merged_ENSG00000001461  1   24742284   24799466  +
# ...                ...                     ... ..        ...        ... ..
# 58444  ENSG00000263502  merged_ENSG00000263502  Y   13340359   13340440  -
# 58445  ENSG00000265161  merged_ENSG00000265161  Y   13947443   13947512  -
# 58446  ENSG00000265197  merged_ENSG00000265197  Y   18398127   18398238  -
# 58447  ENSG00000266220  merged_ENSG00000266220  Y   16364065   16364171  -
# 58448  ENSG00000267793  merged_ENSG00000267793  Y   21760074   21760643  +
#
#        3844   37761  1021.33   76600   730.12   54759  19.9272  3.1573  \
# 0      6354  185623  2639.27  197945  1610.87  120815  31.1528  1.6604
# 1      3524   19690   432.79   32459   143.04   10728   9.2108  1.8604
# 2      8144   87483  1673.53  125515   757.69   56827  15.4120  1.9068
# 3      8514   51422    36.72    2754     6.00     450   0.3235  0.0535
# 4      9404   47779  3795.69  284677   952.16   71412  30.2719  6.2272
# ...     ...     ...      ...     ...      ...     ...      ...     ...
# 58444    82       0     0.00       0     0.00       0   0.0000  0.0000
# 58445    70       0     0.00       0     0.00       0   0.0000  0.0000
# 58446   112       0     0.00       0     0.00       0   0.0000  0.0000
# 58447   107       0     0.00       0     0.00       0   0.0000  0.0000
# 58448   570       0     0.00       0     0.00       0   0.0000  0.0000
#
#        3.6509         SCYL3  protein_coding  \
# 0      5.7077      C1orf112  protein_coding
# 1      1.6876           FGR  protein_coding
# 2      2.8237           CFH  protein_coding
# 3      0.0593         STPG1  protein_coding
# 4      5.5463        NIPAL3  protein_coding
# ...       ...           ...             ...
# 58444  0.0000    AC134878.2           miRNA
# 58445  0.0000    AC011293.1           miRNA
# 58446  0.0000    AC053516.1           miRNA
# 58447  0.0000    AC010723.2           miRNA
# 58448  0.0000  RP11-576C2.1      pseudogene
#
#       SCY1-like_3_(S._cerevisiae)_[Source:HGNC_Symbol;Acc:19285]
# 0      chromosome_1_open_reading_frame_112_[Source:HG...
# 1      Gardner-Rasheed_feline_sarcoma_viral_(v-fgr)_o...
# 2      complement_factor_H_[Source:HGNC_Symbol;Acc:4883]
# 3      sperm-tail_PG-rich_repeat_containing_1_[Source...
# 4      NIPA-like_domain_containing_3_[Source:HGNC_Sym...
# ...                                                  ...
# 58444                                                  -
# 58445                                                  -
# 58446                                                  -
# 58447                                                  -
# 58448                                                  -
#
# [58449 rows x 18 columns]

# %%
test.columns.values.tolist()
# Out:
# ['ENSG00000000457',
#  'merged_ENSG00000000457',
#  '1',
#  '169821804',
#  '169863408',
#  '-',
#  '3844',
#  '37761',
#  '1021.33',
#  '76600',
#  '730.12',
#  '54759',
#  '19.9272',
#  '3.1573',
#  '3.6509',
#  'SCYL3',
#  'protein_coding',
#  'SCY1-like_3_(S._cerevisiae)_[Source:HGNC_Symbol;Acc:19285]']

# %% [markdown]
# # Raw Count

# %% [markdown]
# ## BCCA

# %%
# NCI
patient_arr_NCI = os.listdir("../Raw_Data/BCCA/NCI/")

for id, patient in enumerate(patient_arr_NCI):

    name = patient.rsplit('.')[0]
    temp = pd.read_csv(fr"..\Raw_Data\BCCA\NCI\{patient}", sep="\t").set_index("gene").drop(["RPKM", "median_length_normalized"], axis=1)
    temp = temp.rename(columns={'raw_counts':name})

    if id == 0:
        df_BCCA_Counts = temp
        continue

    df_BCCA_Counts = df_BCCA_Counts.join(temp)

# FHCRC
patient_arr_FHCRC = os.listdir("../Raw_Data/BCCA/FHCRC/")

for id, patient in enumerate(patient_arr_FHCRC):

    name = patient.rsplit('.')[0]

    if name in df_BCCA_Counts: # Only PASIEJ seems to be duplicated
        name = name + "_second"

    temp = pd.read_csv(fr"..\Raw_Data\BCCA\FHCRC\{patient}", sep="\t").set_index("gene").drop(["RPKM", "median_length_normalized"], axis=1)
    temp = temp.rename(columns={'raw_counts':name})
    df_BCCA_Counts = df_BCCA_Counts.join(temp)

# %%
df_BCCA_NCI_Counts = df_BCCA_Counts.iloc[:, :357]
df_BCCA_FHCRC_Counts = df_BCCA_Counts.iloc[:,358:]

# %%
df_BCCA_Counts
# Out:
#                  TARGET-20-PABGKN-09A-01R  TARGET-20-PABHET-03A-02R  \
# gene
# ENSG00000000457                       900                      2270
# ENSG00000000460                       577                      1871
# ENSG00000000938                     11820                       486
# ENSG00000000971                        98                        18
# ENSG00000001460                       360                       920
# ...                                   ...                       ...
# ENSG00000263502                         0                         0
# ENSG00000265161                         0                         0
# ENSG00000265197                         0                         0
# ENSG00000266220                         1                         0
# ENSG00000267793                         0                         0
#
#                  TARGET-20-PABHKY-03A-02R  TARGET-20-PABLDZ-04A-01R  \
# gene
# ENSG00000000457                      1840                       482
# ENSG00000000460                      3605                        75
# ENSG00000000938                      1547                      1286
# ENSG00000000971                       284                         0
# ENSG00000001460                       446                       213
# ...                                   ...                       ...
# ENSG00000263502                         0                         0
# ENSG00000265161                         0                         0
# ENSG00000265197                         0                         0
# ENSG00000266220                         0                         0
# ENSG00000267793                         0                         0
#
#                  TARGET-20-PABLDZ-09A-04R  TARGET-20-PACDZR-09A-02R  \
# gene
# ENSG00000000457                       206                       479
# ENSG00000000460                       622                       413
# ENSG00000000938                      1032                       322
# ENSG00000000971                       166                        68
# ENSG00000001460                       126                       250
# ...                                   ...                       ...
# ENSG00000263502                         0                         0
# ENSG00000265161                         0                         1
# ENSG00000265197                         0                         0
# ENSG00000266220                         0                         0
# ENSG00000267793                         0                         0
#
#                  TARGET-20-PADDXZ-03A-02R  TARGET-20-PADYIR-04A-01R  \
# gene
# ENSG00000000457                       512                       480
# ENSG00000000460                       937                       792
# ENSG00000000938                       746                      4731
# ENSG00000000971                      1037                        70
# ENSG00000001460                       144                       340
# ...                                   ...                       ...
# ENSG00000263502                         0                         0
# ENSG00000265161                         0                         0
# ENSG00000265197                         0                         0
# ENSG00000266220                         0                         0
# ENSG00000267793                        23                        25
#
#                  TARGET-20-PADYIR-09A-01R  TARGET-20-PADZCG-04A-01R  ...  \
# gene                                                                 ...
# ENSG00000000457                       863                       594  ...
# ENSG00000000460                       263                       141  ...
# ENSG00000000938                     14141                     11891  ...
# ENSG00000000971                        24                       215  ...
# ENSG00000001460                       223                       130  ...
# ...                                   ...                       ...  ...
# ENSG00000263502                         0                         0  ...
# ENSG00000265161                         0                         0  ...
# ENSG00000265197                         0                         0  ...
# ENSG00000266220                         0                         0  ...
# ENSG00000267793                        40                         0  ...
#
#                  TARGET-20-PAXMKU-09A-01R  TARGET-20-PAXMLI-09A-01R  \
# gene
# ENSG00000000457                       325                       444
# ENSG00000000460                       106                       805
# ENSG00000000938                      3458                     12354
# ENSG00000000971                        12                        32
# ENSG00000001460                       124                       178
# ...                                   ...                       ...
# ENSG00000263502                         0                         0
# ENSG00000265161                         0                         0
# ENSG00000265197                         0                         0
# ENSG00000266220                         0                         0
# ENSG00000267793                        35                        15
#
#                  TARGET-20-PAXMLN-09A-01R  TARGET-20-PAXMLW-09A-01R  \
# gene
# ENSG00000000457                       590                       729
# ENSG00000000460                       898                       848
# ENSG00000000938                      8893                      7641
# ENSG00000000971                        11                       634
# ENSG00000001460                       135                       164
# ...                                   ...                       ...
# ENSG00000263502                         0                         1
# ENSG00000265161                         0                         0
# ENSG00000265197                         0                         0
# ENSG00000266220                         0                         0
# ENSG00000267793                         0                         0
#
#                  TARGET-20-PAXMNG-09A-01R  TARGET-20-PAXMNR-09A-01R  \
# gene
# ENSG00000000457                       546                       326
# ENSG00000000460                       815                       575
# ENSG00000000938                      8057                     12196
# ENSG00000000971                        31                        43
# ENSG00000001460                       211                       121
# ...                                   ...                       ...
# ENSG00000263502                         0                         3
# ENSG00000265161                         0                         0
# ENSG00000265197                         0                         0
# ENSG00000266220                         0                         0
# ENSG00000267793                         0                        34
#
#                  TARGET-20-PAXMPF-09A-01R  TARGET-20-PAXMPG-09A-01R  \
# gene
# ENSG00000000457                       292                      1487
# ENSG00000000460                       202                      1896
# ENSG00000000938                       787                      1546
# ENSG00000000971                        21                      4535
# ENSG00000001460                        39                       215
# ...                                   ...                       ...
# ENSG00000263502                         0                         0
# ENSG00000265161                         0                         0
# ENSG00000265197                         0                         0
# ENSG00000266220                         0                         0
# ENSG00000267793                         0                         0
#
#                  TARGET-20-PAXMPW-09A-01R  TARGET-20-PAXMRA-09A-01R
# gene
# ENSG00000000457                       528                       699
# ENSG00000000460                       932                      1238
# ENSG00000000938                       689                     13332
# ENSG00000000971                        46                       242
# ENSG00000001460                       267                       216
# ...                                   ...                       ...
# ENSG00000263502                        11                         0
# ENSG00000265161                         0                         0
# ENSG00000265197                         0                         0
# ENSG00000266220                         0                         0
# ENSG00000267793                        81                         0
#
# [58450 rows x 1475 columns]

# %%
df_BCCA_Counts.to_pickle("../Data/BCCA_Counts.pickle")

# %% [markdown]
# ## NCI_Meerzaman
# No metadata

# %%
patient_arr_NCI_M = os.listdir("../Raw_Data/NCI_Meerzaman/")

for id, patient in enumerate(patient_arr_NCI_M):

    name = patient.rsplit('.')[0]
    temp = pd.read_csv(fr"..\Raw_Data\NCI_Meerzaman\{patient}", sep="\t").set_index("gene").drop(["rpkm"], axis=1)
    temp = temp.rename(columns={'raw_count':name})

    if id == 0:
        df_NCI_M_Counts = temp
        continue

    df_NCI_M_Counts = df_NCI_M_Counts.join(temp)

# %%
df_NCI_M_Counts

# %% [markdown]
# # Export

# %% [markdown]
# ## BCCA

# %%
# RPKM
with open('../Datasets/BCCA_RPKM.pickle', 'wb') as f:
    pickle.dump(df_BCCA_RPKM, f)

# Counts
with open('../Datasets/BCCA_Counts.pickle', 'wb') as f:
    pickle.dump(df_BCCA_Counts, f)

### BCCA_NCI ###
# RPKM
with open('../Datasets/BCCA_NCI_RPKM.pickle', 'wb') as f:
    pickle.dump(df_BCCA_NCI_RPKM, f)

# Counts
with open('../Datasets/BCCA_NCI_Counts.pickle', 'wb') as f:
    pickle.dump(df_BCCA_NCI_Counts, f)

### BCCA_FHCRC ###
# RPKM
with open('../Datasets/BCCA_FHCRC_RPKM.pickle', 'wb') as f:
    pickle.dump(df_BCCA_FHCRC_RPKM, f)

# Counts
with open('../Datasets/BCCA_FHCRC_Counts.pickle', 'wb') as f:
    pickle.dump(df_BCCA_FHCRC_Counts, f)

# %% [markdown]
# ## FHCRC Low Depth (Only RPKM)

# %%
# FHCRC_Low_Depth RPKM
with open('../Datasets/FHCRC_Low_Depth_RPKM.pickle', 'wb') as f:
    pickle.dump(df_FHCRC_LD, f)

# %% [markdown]
# ## NCI Meerzaman (Find Metadata)

# %%
# RPKM
with open('../Datasets/NCI_Meerzaman_RPKM.pickle', 'wb') as f:
    pickle.dump(df_NCI_M_RPKM, f)

# Counts
with open('../Datasets/NCI_Meerzaman_Counts.pickle', 'wb') as f:
    pickle.dump(df_NCI_M_Counts, f)
